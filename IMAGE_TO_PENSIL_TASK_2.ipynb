# %% [markdown]
# <a href="https://colab.research.google.com/github/swapnil2001/image_to_pencil/blob/main/IMAGE_TO_PENSIL_TASK_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **NAME: VIVEK RAJENDRA DHOKANE**
#
# ## **DATASCIENCE INTERN @LGM**
#
# ## **LetsGrowMore VIP**
#
# **Task : 02**
#
# **Task:  Convert Image into Pencil Sketch with Python:**
#
# **We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.**

# %%
from google.colab import drive

# %%
#importing requried libraries
import cv2
from google.colab.patches import cv2_imshow

# %%
#Reading the image in BGR format
pic=cv2.imread("/content/david beckum.jpg",1)
cv2_imshow(pic)
# Out:
# <PIL.Image.Image image mode=RGB size=900x600 at 0x7FC8E2F3EDD0>

# %%
rgbpic = cv2.cvtColor(pic,cv2.COLOR_BGR2RGB)
cv2_imshow(rgbpic)
grayscale= cv2.cvtColor(rgbpic,cv2.COLOR_RGB2GRAY)
# Out:
# <PIL.Image.Image image mode=RGB size=900x600 at 0x7FC8E2EFA3D0>

# %%
#Converting a RGB image into gray_scale image
grayscale= cv2.cvtColor(rgbpic,cv2.COLOR_RGB2GRAY)
cv2_imshow(grayscale)
# Out:
# <PIL.Image.Image image mode=L size=900x600 at 0x7FC8E2E89690>

# %%
#Inverting the image
invert=cv2.bitwise_not(grayscale)
cv2_imshow(invert)
# Out:
# <PIL.Image.Image image mode=L size=900x600 at 0x7FC8E2E83050>

# %%
#GaussianBlur
gaussblur=cv2.GaussianBlur(invert,(15, 15),sigmaX=0,sigmaY=0)
cv2_imshow(gaussblur)
# Out:
# <PIL.Image.Image image mode=L size=900x600 at 0x7FC8E2E8AFD0>

# %%
#Pencil_Sketch
pencil_sketch = cv2.divide(grayscale, 255 - gaussblur, scale=256)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=900x600 at 0x7FC8E2E913D0>

# %% [markdown]
# **THANK YOU!**
